# %%
print("Hello world")
# Out:
# Hello world

# %% [markdown]
# # 1. 구글 코랩 기초 사용법
# 맥북은 cmd 윈도우는 ctrl
#
# 1. (필수) Ctrl(Command) + Enter : 해당 셀 실행![zoom_BG.png](data:image/png;base64,...)

# %%
print("모두연")
# Out:
# 모두연

# %% [markdown]
# 2. (필수) Alt(Option) + Enter : 해당 셀 실행 + 코드 불록 하단 추가

# %% [markdown]
# # 2. 실행 관련 단축키

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# 3. Ctrl(Command) + M A : 코드 셀 위에 삽입
# 4. Ctrl(Command) + M B : 코드 셀 아래 삽입
# 5. Ctrl(Command) + M D : 셀 지우기
# 6. Ctrl(Command) + M Y : 코드 셀로 변경
# 7. Ctrl(Command) + M M : 마크다운 셀로 변경
# 8. Ctrl(Command) + M Z : 실행 취소

# %% [markdown]
# # 3. 수정 관련된 단축키
# 1. `Ctrl(Command)` + `Alt(Option)` + 화살표위아래 : 동시 수정
# - 자주 쓰는 예시 필요
# 2. (자주) `Ctrl(Command)` + D : 같은 단어 찾아 동시 수정
# 3. `Ctrl(Command)` + `Shift` + L : 동일 단어를 전체로 찾아 동시 수정
# 4. `Alt(Option)` + `Shift` + 화살표위아래 : 해당내용을 위나 아래 복사해서 붙여넣기
# 5. `Alt(Option)` + 화살표위아래 : 해당 내용을 위나 아래로 보내기
# 6. (자주) `Ctrl(Command)` + `Alt(Option)` + 화살표위아래 : 위아래 동시 수정
# 7. (자주) Home, End : 문장의 양 끝
# 8. (필수) `Ctrl` + `/` : 주석
# 9. (필수) `Shift`(cmd) + `Del` : 한 줄 지우기
# 10. (필수) `Tab`, `Ctrl` + `]` : 들여쓰기
# 11. (필수) `Shift` + `Tab`, `Ctrl` + `[` : 내어쓰기

# %%
# 1. 제목

# %%
# 데이터셋 불러오기
import pandas as pd
data = pd.read_csv("example_dataset.csv")

# 각 컬럼에 대한 평균 계산
mean_age = data['age'].mean()
mean_height = data['height'].mean()
mean_weight = data['weight'].mean()

print("Average Age:", mean_age)
print("Average Height:", mean_height)
print("Average Weight:", mean_weight)
# Out:
#   File "<ipython-input-11-b412e8398b0b>", line 1
#     데이터셋 불러오기
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 4. 마크다운
# ## 4.1 헤더
# ### 4.1.1 사용법
#
# 제목을 입력하는 기능

# %% [markdown]
# ## 4.2 강조
#
# 이 내용은 **강조** 해야하는 *문장* 입니다.
# *강조*
# **강조**

# %% [markdown]
# ## 4.3 목록(Lists)
#
# 1. 순서 1번
# 2. 순서 2번
# 3. 순서 3번
#
# * 순서 없는 것 1
# * 순서 없는 것 2
# * 순서 없는 것 3

# %% [markdown]
# # 4.4 링크
#
# * 사용법: [텍스트](URL) 형식을 사용하여 하이퍼링크를 삽입합니다.
# * [Pyalgo](https://pyalgo.co.kr/)

# %% [markdown]
# # 4.5 이미지
# * 사용법: ![대체 텍스트](이미지 URL) 형식을 사용하여 이미지를 삽입합니다. 대체 텍스트는 이미지가 표시되지 않을 때 나타나는 텍스트입니다
#
# ![Licat](https://paullab.co.kr/images/message_licat.png)

# %% [markdown]
# # 4.6 코드
#
# - **인라인 코드**: `를 사용하여 텍스트 내에 코드를 삽입합니다.
# - **코드 블록**: 여러 줄의 코드를 나타낼 때는 **`````**를 사용하여 코드 블록을 생성합니다.
#
# `print("Hello World")`
# 'print("Hello World")'
# → print("Hello World")

# %% [markdown]
# #4.7 기타
#
# * 취소선 ~~취소선~~
# ---
# * 인용문
# > 인용문 1입니다.
# >> 인용문 1-1입니다.
# ---
# * 구분선
# ---
#
# ---
